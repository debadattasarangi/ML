# %% [markdown]
# # Pandas
# Pandas is an open-source Python Library providing high-performance data manipulation and analysis tool using its powerful data structures.Prior to Pandas, Python was majorly used for data munging and preparation. It had very little contribution towards data analysis. Pandas solved this problem. Using Pandas, we can accomplish five typical steps in the processing and analysis of data, regardless of the origin of data — load, prepare, manipulate, model, and analyze.

# %% [markdown]
# # Series
# A Series is a one-dimensional array-like object containing an array of data (of any
# NumPy data type) and an associated array of data labels, called its index.
#  obj = Series([4, 7, -5, 3])

# %%
import pandas as pd

# %%
obj=pd.Series([4,7,3,9])

# %%
obj
# Out:
# 0    4
# 1    7
# 2    3
# 3    9
# dtype: int64

# %%
obj.values
# Out:
# array([4, 7, 3, 9], dtype=int64)

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj[obj>4]
# Out:
# 1    7
# 3    9
# dtype: int64

# %%
 sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}

# %%
states = ['California', 'Ohio', 'Oregon', 'Texas']
obj4 = pd.Series(sdata, index=states)

# %%
obj4
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
type(obj4)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # DataFrame

# %% [markdown]
# A DataFrame represents a tabular, spreadsheet-like data structure containing an ordered collection of columns, each of which can be a different value type (numeric,
# string, boolean, etc.). The DataFrame has both a row and column index; it can be
# thought of as a dict of Series (one for all sharing the same index)

# %%
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada'],
 'year': [2000, 2001, 2002, 2001, 2002],
 'pop': [1.5, 1.7, 3.6, 2.4, 2.9]}
frame = pd.DataFrame(data)

# %%
frame.columns
# Out:
# Index(['state', 'year', 'pop'], dtype='object')

# %%
frame[0:3]
# Out:
#   state  year  pop
# 0  Ohio  2000  1.5
# 1  Ohio  2001  1.7
# 2  Ohio  2002  3.6

# %%
frame.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
frame.iloc[0:2]
# Out:
#   state  year  pop
# 0  Ohio  2000  1.5
# 1  Ohio  2001  1.7

# %%
frame.loc[1:2]
# Out:
#   state  year  pop
# 1  Ohio  2001  1.7
# 2  Ohio  2002  3.6

# %%
frame.values
# Out:
# array([['Ohio', 2000, 1.5],
#        ['Ohio', 2001, 1.7],
#        ['Ohio', 2002, 3.6],
#        ['Nevada', 2001, 2.4],
#        ['Nevada', 2002, 2.9]], dtype=object)

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
# state    5 non-null object
# year     5 non-null int64
# pop      5 non-null float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 248.0+ bytes

# %%
frame.describe()
# Out:
#              year       pop
# count     5.00000  5.000000
# mean   2001.20000  2.420000
# std       0.83666  0.864292
# min    2000.00000  1.500000
# 25%    2001.00000  1.700000
# 50%    2001.00000  2.400000
# 75%    2002.00000  2.900000
# max    2002.00000  3.600000

# %%
frame.year
# Out:
# 0    2000
# 1    2001
# 2    2002
# 3    2001
# 4    2002
# Name: year, dtype: int64

# %%
d=frame[frame.year==2000]

# %%
d
# Out:
#   state  year  pop
# 0  Ohio  2000  1.5

# %%
frame.isnull()
# Out:
#    state   year    pop
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False
# 4  False  False  False

# %%
frame.isnull().sum()
# Out:
# state    0
# year     0
# pop      0
# dtype: int64

# %%
frame.isnull().any(0)
# Out:
# state    False
# year     False
# pop      False
# dtype: bool

# %%
frame.nunique()
# Out:
# state    2
# year     3
# pop      5
# dtype: int64

# %%
frame.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
frame.drop_duplicates(inplace=True)

# %%
a=frame.groupby(['year']).count()

# %%
a
# Out:
#       state  pop
# year
# 2000      1    1
# 2001      2    2
# 2002      2    2

# %%
b=frame.groupby(['state']).count()

# %%
b
# Out:
#         year  pop
# state
# Nevada     2    2
# Ohio       3    3

# %%
frame.drop(columns='pop',axis=1)
# Out:
#     state  year
# 0    Ohio  2000
# 1    Ohio  2001
# 2    Ohio  2002
# 3  Nevada  2001
# 4  Nevada  2002

# %%
frame.shape[1]
# Out:
# 3

# %%
frame.dropna(axis=0)#row
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %%
from PIL import Image 
pic = Image.open("Pandas_1.png") 
pic
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=593x330 at 0x29DDD024A48>

# %%
from PIL import Image 
pic = Image.open("Pandas_2.png") 
pic
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=622x260 at 0x29DDD0355C8>

# %%
frame.ix[0]
# Out:
# C:\Users\debad\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# state    Ohio
# year     2000
# pop       1.5
# Name: 0, dtype: object

# %%
from PIL import Image 
pic = Image.open("Pandas_3.png") 
pic
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=351x123 at 0x29DDD035DC8>

# %%
from PIL import Image 
pic = Image.open("Pandas_4.png") 
pic
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=600x468 at 0x29DDD03C448>

# %%
from PIL import Image 
pic = Image.open("Pandas_5.png") 
pic
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=657x93 at 0x29DDD03CA88>

# %%
from PIL import Image 
pic = Image.open("Pandas_6.png") 
pic
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=628x148 at 0x29DDD03E188>

# %%
from PIL import Image 
pic = Image.open("Pandas_7.png") 
pic
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=633x127 at 0x29DDD03E888>

# %%
from PIL import Image 
pic = Image.open("Pandas_8.png") 
pic
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=680x676 at 0x29DDD035248>

# %% [markdown]
# # Merge

# %%
df1 = pd.DataFrame({'key': ['b', 'b', 'a', 'c', 'a', 'b'],'data1': range(6)})
df2 = pd.DataFrame({'key': ['a', 'b', 'a', 'b', 'd'],'data2': range(5)})

# %%
d=pd.merge(df1, df2, on='key', how='left')

# %%
d
# Out:
#    key  data1  data2
# 0    b      0    1.0
# 1    b      0    3.0
# 2    b      1    1.0
# 3    b      1    3.0
# 4    a      2    0.0
# 5    a      2    2.0
# 6    c      3    NaN
# 7    a      4    0.0
# 8    a      4    2.0
# 9    b      5    1.0
# 10   b      5    3.0

# %%
r=pd.merge(df1, df2, on='key', how='right')

# %%
r
# Out:
#    key  data1  data2
# 0    b    0.0      1
# 1    b    1.0      1
# 2    b    5.0      1
# 3    b    0.0      3
# 4    b    1.0      3
# 5    b    5.0      3
# 6    a    2.0      0
# 7    a    4.0      0
# 8    a    2.0      2
# 9    a    4.0      2
# 10   d    NaN      4

# %%
from PIL import Image 
pic = Image.open("Pandas_9.png") 
pic
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=627x387 at 0x29DDD058F08>
